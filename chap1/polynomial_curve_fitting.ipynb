# %%
from scipy.stats import stats
import random
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sample_size = 100
x_values = [2 * np.pi * random.random() for _ in range(sample_size)]
y_values = np.sin(x_values) + (np.random.normal(loc=0, scale=0.1, size=sample_size))
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# %%
x_values
# Out:
# [0.9005921751072422,
#  6.277531264946927,
#  3.6193331109309543,
#  1.7140363839987012,
#  1.076535629829091,
#  5.660406371400365,
#  2.240828583500949,
#  3.2459810346856477,
#  0.08250537550656388,
#  4.559967129420364]

# %%
y_values
# Out:
# array([ 0.78369487, -0.00565401, -0.4597738 ,  0.98975867,  0.88031966,
#        -0.58329463,  0.78380163, -0.1041989 ,  0.0824118 , -0.98840626])

# %%
sns.scatterplot(x=x_values, y=y_values)
sns.lineplot(x=x, y=y, color="green")
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(-1.01, 1.01)
# Out:
# (-1.01, 1.01)
